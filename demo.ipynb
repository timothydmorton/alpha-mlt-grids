# %%
from alpha_mlt import AlphaMLTGrid, AlphaMLTInterpolator, AlphaMLTStarModel, AlphaMLT_EEP_prior

amlt = AlphaMLTInterpolator()

mags = {"G": (14.86, 0.01), "BP": (15.77, 0.01), "RP": (13.95, 0.01)}

mod = AlphaMLTStarModel(amlt, **mags, parallax=(10, 0.05), name="alpha-test", maxAV=0.1)

# %%
pars = [0.3, 270, -1.0, 0.8, 100, 0.1]  # these are actual params
mod.lnlike(pars)
# Out:
# -20.997220432277256

# %%
mod.lnprior(pars)
# Out:
# -16.183990718996363

# %%
mod.fit()

# %%
mod.corner_physical();
